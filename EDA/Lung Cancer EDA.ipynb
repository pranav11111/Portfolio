# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cancer =  pd.read_excel('Lung Cancer Survey.xlsx')

# %%
cancer.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
cancer.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
cancer.LUNG_CANCER.value_counts(normalize =  True)
# Out:
# YES    0.873786
# NO     0.126214
# Name: LUNG_CANCER, dtype: float64

# %%
cancer.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# - No null data

# %%
cancer.LUNG_CANCER = cancer.LUNG_CANCER.replace( ["YES",'NO'],[1,0])

# %%
cancer.LUNG_CANCER.value_counts(normalize = True)
# Out:
# 1    0.873786
# 0    0.126214
# Name: LUNG_CANCER, dtype: float64

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cancer.corr(), cmap= 'gist_rainbow',annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Age, Smoking, Shortness of breath have very very low correlation with lung cancer
# - Anxiety has modreatly  high corr with Yellow fingers and swallowing difficulty
# - Yellow finger seems to be related modrately with swallowing difficulty and peer pressure

# %% [markdown]
# # Univariate analysis

# %%
cancer.GENDER.value_counts(normalize =  True)
# Out:
# M    0.524272
# F    0.475728
# Name: GENDER, dtype: float64

# %% [markdown]
# - Almost the same number of males as females with Males being a bit more

# %%
cancer.SMOKING.value_counts(normalize =  True)
# Out:
# 2    0.563107
# 1    0.436893
# Name: SMOKING, dtype: float64

# %% [markdown]
# - Amount of people who smoke are more

# %%
cancer.YELLOW_FINGERS.value_counts(normalize =  True)
# Out:
# 2    0.569579
# 1    0.430421
# Name: YELLOW_FINGERS, dtype: float64

# %% [markdown]
# - There are more people with YELLOW FINGERS

# %%
cancer.ANXIETY.value_counts(normalize =  True)
# Out:
# 1    0.501618
# 2    0.498382
# Name: ANXIETY, dtype: float64

# %% [markdown]
# - The number of people have anxiety are the same as the number of people who dont

# %%
cancer.PEER_PRESSURE.value_counts(normalize =  True)
# Out:
# 2    0.501618
# 1    0.498382
# Name: PEER_PRESSURE, dtype: float64

# %%
cancer["CHRONIC DISEASE"].value_counts(normalize =  True)
# Out:
# 2    0.504854
# 1    0.495146
# Name: CHRONIC DISEASE, dtype: float64

# %%
cancer["FATIGUE "].value_counts(normalize =  True)
# Out:
# 2    0.673139
# 1    0.326861
# Name: FATIGUE , dtype: float64

# %%
cancer["ALLERGY "].value_counts(normalize =  True)
# Out:
# 2    0.556634
# 1    0.443366
# Name: ALLERGY , dtype: float64

# %%
cancer["WHEEZING"].value_counts(normalize =  True)
# Out:
# 2    0.556634
# 1    0.443366
# Name: WHEEZING, dtype: float64

# %%
cancer["ALCOHOL CONSUMING"].value_counts(normalize =  True)
# Out:
# 2    0.556634
# 1    0.443366
# Name: ALCOHOL CONSUMING, dtype: float64

# %%
cancer["COUGHING"].value_counts(normalize =  True)
# Out:
# 2    0.579288
# 1    0.420712
# Name: COUGHING, dtype: float64

# %%
cancer["SHORTNESS OF BREATH"].value_counts(normalize =  True)
# Out:
# 2    0.640777
# 1    0.359223
# Name: SHORTNESS OF BREATH, dtype: float64

# %%
cancer["SWALLOWING DIFFICULTY"].value_counts(normalize =  True)
# Out:
# 1    0.530744
# 2    0.469256
# Name: SWALLOWING DIFFICULTY, dtype: float64

# %%
cancer["CHEST PAIN"].value_counts(normalize =  True)
# Out:
# 2    0.556634
# 1    0.443366
# Name: CHEST PAIN, dtype: float64

# %%
cancer["LUNG_CANCER"].value_counts(normalize =  True)
# Out:
# 1    0.873786
# 0    0.126214
# Name: LUNG_CANCER, dtype: float64

# %%
sns.displot(cancer['AGE'] , kde= True)

# %%
sns.violinplot(x =  "AGE",data = cancer )
# Out:
# <AxesSubplot:xlabel='AGE'>

# %% [markdown]
# - slightly left skewed

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(hue = 'LUNG_CANCER' , x = "GENDER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(hue = 'ANXIETY' , x = "GENDER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(hue = 'PEER_PRESSURE' , x = "GENDER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(hue = 'ALCOHOL CONSUMING' , x = "GENDER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# #### Comparison of features w.t.r Gender
# - More number of men have cancer as compared to women
# - More females have anxity issues as compared to men
# - More females have faced peer pressure as compared to men
# - More men consume alcohol compared to women

# %%
sns.countplot(hue = 'ALCOHOL CONSUMING' , x = "LUNG_CANCER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot(hue = 'SMOKING' , x = "LUNG_CANCER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot(hue = 'YELLOW_FINGERS' , x = "LUNG_CANCER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot(hue = 'ANXIETY' , x = "LUNG_CANCER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot(hue = 'PEER_PRESSURE' , x = "LUNG_CANCER",data =  cancer)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'CHRONIC DISEASE' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'FATIGUE ' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'ALLERGY ' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'WHEEZING' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'COUGHING' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'SHORTNESS OF BREATH' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'SWALLOWING DIFFICULTY' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
sns.countplot( x = "LUNG_CANCER",data =  cancer,hue = 'CHEST PAIN' )
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %% [markdown]
# #### Comparison of lung cancer with respect to other variables
# - Execpt for SHORTNESS OF BREATH all other symptoms having people have higher chance of having cancer
# - Even though people not having any symptoms also have a high chance of having cancer the ratio is significantly higher for people having symptoms
# - The symptoms or variables which have could be classified as serious are:-
#     - Alcohol consumption
#     - Allergy
#     - Wheezing
#     - Coughing
#     - Swallowing difficuilty
# - This can be inferred from the fact that there are not many people having these symptoms / variables who dont have cancer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('original_aerofit_treadmill.csv')
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
data.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66
# 6   KP281   21  Female         14     Partnered      3        3   35247     75
# 7   KP281   21    Male         13        Single      3        3   32973     85
# 8   KP281   21    Male         15        Single      5        4   35247    141
# 9   KP281   21  Female         15     Partnered      2        3   37521     85

# %%
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
data.shape
# Out:
# (180, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# //add infernce for min and max values

# %%
data['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %% [markdown]
# //inference for unique products available

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# //inference for unique gender available

# %%
data['MaritalStatus'].unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %% [markdown]
# //inference for unique MaritalStatus available

# %% [markdown]
# Q4 purchase % of each treadmill

# %%
round(data['Product'].value_counts(normalize = True),2)
# Out:
# KP281    0.44
# KP481    0.33
# KP781    0.22
# Name: Product, dtype: float64

# %% [markdown]
# // count of people having products

# %% [markdown]
# # univariate

# %%
sns.countplot(x = data['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x = data['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.displot(x = data['Education'], kind = 'kde')

# %%
sns.countplot(x = data['MaritalStatus'])
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
sns.countplot(x = data['Usage'])
# Out:
# <Axes: xlabel='Usage', ylabel='count'>

# %%
sns.countplot(x = data['Fitness'])
# Out:
# <Axes: xlabel='Fitness', ylabel='count'>

# %%
sns.displot(x = data['Age'], kind = 'kde')

# %%
sns.displot(x = data['Income'], kind = 'kde')

# %%
sns.displot(x = data['Miles'], kind = 'kde')

# %% [markdown]
# #bivariate

# %%
sns.boxplot(data=data, x="Product", y="Age")
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
sns.boxplot(data=data, x="Product", y="Education")
# Out:
# <Axes: xlabel='Product', ylabel='Education'>

# %%
sns.boxplot(data=data, x="Product", y="Income")
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.boxplot(data=data, x="Product", y="Miles")
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %% [markdown]
# Q3 Check if features like marital status, age have any effect on the product purchased (using countplot, histplots, boxplots etc)

# %%
sns.countplot(data = data, hue = data['MaritalStatus'], x = data['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
plt.figure(figsize = [15, 5])
sns.countplot(data = data, x = data['Age'],  hue = data['Product'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data = data, hue = data['Gender'], x = data['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(data = data, hue = data['Fitness'], x = data['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %% [markdown]
# Q5 Check correlation among different factors using heat maps or pair plots.

# %% [markdown]
# #multivariate

# %%
def test(x) :
  if x == 'KP281' :
    return 1
  elif x == 'KP481' :
    return 2
  else :
    return 3

data['ProductType'] = data['Product'].apply(test)

sns.heatmap(data.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <ipython-input-183-14708bc27fa7>:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True, cmap = 'coolwarm')
# <Axes: >

# %% [markdown]
# add notes

# %% [markdown]
# Q6 With all the above steps you can answer questions like: What is the probability of a male customer buying a KP781 treadmill?

# %%
def age_group(x):
  if x <= 24 :
    return 'Young Adults'
  elif x <= 30 :
    return 'Early Adults'
  elif x <= 40 :
    return 'Adults'
  else :
    return 'Late Adults'

data['AgeGroup'] = data['Age'].apply(age_group)

age_df = pd.crosstab(columns = data['AgeGroup'], index = data['Product'], margins = True, margins_name = 'Total')
age_vals = np.sort(data['AgeGroup'].unique().tolist())
for i in age_vals :
  col_name = str(i) + " probabilty"
  age_df[col_name] = round(age_df[i]/age_df['Total'], 2)
age_df.drop('Total', axis = 0, inplace = True)
age_df
# Out:
# AgeGroup  Adults  Early Adults  Late Adults  Young Adults  Total  \
# Product
# KP281         19            28            6            27     80
# KP481         23            18            2            17     60
# KP781          6            20            4            10     40
#
# AgeGroup  Adults probabilty  Early Adults probabilty  Late Adults probabilty  \
# Product
# KP281                  0.24                     0.35                    0.08
# KP481                  0.38                     0.30                    0.03
# KP781                  0.15                     0.50                    0.10
#
# AgeGroup  Young Adults probabilty
# Product
# KP281                        0.34
# KP481                        0.28
# KP781                        0.25

# %%
gender_df = pd.crosstab(columns = data['Gender'], index = data['Product'], margins = True, margins_name = 'Total')
gender_vals = np.sort(data['Gender'].unique().tolist())
for i in gender_vals :
  col_name = str(i) + " probabilty"
  gender_df[col_name] = round(gender_df[i]/gender_df['Total'], 2)
gender_df.drop('Total', axis = 0, inplace = True)
gender_df
# Out:
# Gender   Female  Male  Total  Female probabilty  Male probabilty
# Product
# KP281        40    40     80               0.50             0.50
# KP481        29    31     60               0.48             0.52
# KP781         7    33     40               0.18             0.82

# %%
education_df = pd.crosstab(columns = data['Education'], index = data['Product'], margins = True, margins_name = 'Total')
education_vals = np.sort(data['Education'].unique().tolist())
for i in education_vals :
  col_name = str(i) + " probabilty"
  education_df[col_name] = round(education_df[i]/education_df['Total'], 2)
education_df.drop('Total', axis = 0, inplace = True)
education_df
# Out:
# Education  12  13  14  15  16  18  20  21  Total  12 probabilty  \
# Product
# KP281       2   3  30   4  39   2   0   0     80           0.02
# KP481       1   2  23   1  31   2   0   0     60           0.02
# KP781       0   0   2   0  15  19   1   3     40           0.00
#
# Education  13 probabilty  14 probabilty  15 probabilty  16 probabilty  \
# Product
# KP281               0.04           0.38           0.05           0.49
# KP481               0.03           0.38           0.02           0.52
# KP781               0.00           0.05           0.00           0.38
#
# Education  18 probabilty  20 probabilty  21 probabilty
# Product
# KP281               0.02           0.00           0.00
# KP481               0.03           0.00           0.00
# KP781               0.48           0.02           0.08

# %%
MaritalStatus_df = pd.crosstab(columns = data['MaritalStatus'], index = data['Product'], margins = True, margins_name = 'Total')
MaritalStatus_vals = np.sort(data['MaritalStatus'].unique().tolist())
for i in MaritalStatus_vals :
  col_name = str(i) + " probabilty"
  MaritalStatus_df[col_name] = round(MaritalStatus_df[i]/MaritalStatus_df['Total'], 2)
MaritalStatus_df.drop('Total', axis = 0, inplace = True)
MaritalStatus_df
# Out:
# MaritalStatus  Partnered  Single  Total  Partnered probabilty  \
# Product
# KP281                 48      32     80                  0.60
# KP481                 36      24     60                  0.60
# KP781                 23      17     40                  0.57
#
# MaritalStatus  Single probabilty
# Product
# KP281                       0.40
# KP481                       0.40
# KP781                       0.42

# %%
usage_df = pd.crosstab(columns = data['Usage'], index = data['Product'], margins = True, margins_name = 'Total')
usage_vals = np.sort(data['Usage'].unique().tolist())
for i in usage_vals :
  col_name = str(i) + " probabilty"
  usage_df[col_name] = round(usage_df[i]/usage_df['Total'], 2)
usage_df.drop('Total', axis = 0, inplace = True)
usage_df
# Out:
# Usage     2   3   4   5  6  7  Total  2 probabilty  3 probabilty  \
# Product
# KP281    19  37  22   2  0  0     80          0.24          0.46
# KP481    14  31  12   3  0  0     60          0.23          0.52
# KP781     0   1  18  12  7  2     40          0.00          0.02
#
# Usage    4 probabilty  5 probabilty  6 probabilty  7 probabilty
# Product
# KP281            0.28          0.02          0.00          0.00
# KP481            0.20          0.05          0.00          0.00
# KP781            0.45          0.30          0.18          0.05

# %%
fitness_df = pd.crosstab(columns = data['Fitness'], index = data['Product'], margins = True, margins_name = 'Total')
fitness_vals = np.sort(data['Fitness'].unique().tolist())
for i in fitness_vals :
  col_name = str(i) + " probabilty"
  fitness_df[col_name] = round(fitness_df[i]/fitness_df['Total'], 2)
fitness_df.drop('Total', axis = 0, inplace = True)
fitness_df
# Out:
# Fitness  1   2   3  4   5  Total  1 probabilty  2 probabilty  3 probabilty  \
# Product
# KP281    1  14  54  9   2     80          0.01          0.18          0.68
# KP481    1  12  39  8   0     60          0.02          0.20          0.65
# KP781    0   0   4  7  29     40          0.00          0.00          0.10
#
# Fitness  4 probabilty  5 probabilty
# Product
# KP281            0.11          0.02
# KP481            0.13          0.00
# KP781            0.18          0.72

# %%
def income_group(x):
  if x <= 54568 :
    return 'Low-income'
  elif x <= 79574 :
    return 'Medium-income'
  else :
    return 'High-income'

data['IncomeGroup'] = data['Income'].apply(income_group)

income_df = pd.crosstab(columns = data['IncomeGroup'], index = data['Product'], margins = True, margins_name = 'Total')
income_vals = np.sort(data['IncomeGroup'].unique().tolist())
for i in income_vals :
  col_name = str(i) + " probabilty"
  income_df[col_name] = round(income_df[i]/income_df['Total'], 2)
income_df.drop('Total', axis = 0, inplace = True)
income_df
# Out:
# IncomeGroup  High-income  Low-income  Medium-income  Total  \
# Product
# KP281                  0          62             18     80
# KP481                  0          47             13     60
# KP781                 19           8             13     40
#
# IncomeGroup  High-income probabilty  Low-income probabilty  \
# Product
# KP281                          0.00                   0.78
# KP481                          0.00                   0.78
# KP781                          0.48                   0.20
#
# IncomeGroup  Medium-income probabilty
# Product
# KP281                            0.22
# KP481                            0.22
# KP781                            0.32

# %%
def miles_group(x):
  if x <= 134 :
    return 'Low-miles'
  elif x <= 247 :
    return 'Medium-miles'
  else :
    return 'High-miles'

data['MilesGroup'] = data['Miles'].apply(miles_group)

miles_df = pd.crosstab(columns = data['MilesGroup'], index = data['Product'], margins = True, margins_name = 'Total')
miles_vals = np.sort(data['MilesGroup'].unique().tolist())
for i in miles_vals :
  col_name = str(i) + " probabilty"
  miles_df[col_name] = round(miles_df[i]/miles_df['Total'], 2)
miles_df.drop('Total', axis = 0, inplace = True)
miles_df
# Out:
# MilesGroup  High-miles  Low-miles  Medium-miles  Total  High-miles probabilty  \
# Product
# KP281                0         76             4     80                    0.0
# KP481                0         57             3     60                    0.0
# KP781                4         12            24     40                    0.1
#
# MilesGroup  Low-miles probabilty  Medium-miles probabilty
# Product
# KP281                       0.95                     0.05
# KP481                       0.95                     0.05
# KP781                       0.30                     0.60
